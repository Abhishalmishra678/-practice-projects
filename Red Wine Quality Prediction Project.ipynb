# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
DF= pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/winequality-red.csv')
DF.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
DATA = DF

# %%
DATA.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5
# 5      9.4        5
# 6      9.4        5
# 7     10.0        7
# 8      9.5        7
# 9     10.5        5

# %%
DATA.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1589            6.6             0.725         0.20             7.8      0.073
# 1590            6.3             0.550         0.15             1.8      0.077
# 1591            5.4             0.740         0.09             1.7      0.089
# 1592            6.3             0.510         0.13             2.3      0.076
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1589                 29.0                  79.0  0.99770  3.29       0.54
# 1590                 26.0                  35.0  0.99314  3.32       0.82
# 1591                 16.0                  26.0  0.99402  3.67       0.56
# 1592                 29.0                  40.0  0.99574  3.42       0.75
# 1593                 28.0                  38.0  0.99651  3.42       0.82
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1589      9.2        5
# 1590     11.6        6
# 1591     11.6        6
# 1592     11.0        6
# 1593      9.5        6
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %% [markdown]
# #as par my obsarvetiom all 11 colmns  and 1 target colmnS contain INT VALUEA ,MENES THARE IS NO CATAGARICAL DATA.

# %%
DATA.shape
# Out:
# (1599, 12)

# %%
DATA.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %% [markdown]
# #total number of rows(data)is 1599 and colmns are 12 the last column(quality)is target variable and rest are indipendent.

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# #as par my obsarvation no null value found in dataset as well as all  datatype of all colmns are correct .

# %%
DATA.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# #no null value present im data

# %%
sns.heatmap(DATA.isnull())
# Out:
# <Axes: >

# %% [markdown]
# #color representetoin of null values {no null value found}

# %%
DATA.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %% [markdown]
# #cheking for unique values

# %%
DATA.nunique().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #in above grafical represention of uniqe values , a column name "density" has the most unique values
# #and the target column has the minimum unique values

# %%
for i in DATA.columns:
    print(DATA[i].value_counts())
    print('/n'*45)
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# Name: chlorides, Length: 153, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 6.0     138
# 5.0     104
# 10.0     79
# 15.0     78
# 12.0     75
# 7.0      71
# 9.0      62
# 16.0     61
# 17.0     60
# 11.0     59
# 13.0     57
# 8.0      56
# 14.0     50
# 3.0      49
# 18.0     46
# 4.0      41
# 21.0     41
# 19.0     39
# 24.0     34
# 26.0     32
# 23.0     32
# 20.0     30
# 27.0     29
# 25.0     24
# 29.0     23
# 28.0     23
# 22.0     22
# 32.0     22
# 31.0     20
# 34.0     18
# 30.0     16
# 35.0     15
# 36.0     11
# 33.0     11
# 38.0      9
# 41.0      7
# 40.0      6
# 39.0      5
# 48.0      4
# 51.0      4
# 45.0      3
# 1.0       3
# 43.0      3
# 42.0      3
# 52.0      3
# 37.0      3
# 68.0      2
# 55.0      2
# 50.0      2
# 37.5      2
# 53.0      1
# 72.0      1
# 57.0      1
# 47.0      1
# 5.5       1
# 2.0       1
# 46.0      1
# 54.0      1
# 40.5      1
# 66.0      1
# Name: free sulfur dioxide, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 28.0     43
# 24.0     36
# 15.0     35
# 18.0     35
# 23.0     34
#          ..
# 139.0     1
# 149.0     1
# 152.0     1
# 155.0     1
# 165.0     1
# Name: total sulfur dioxide, Length: 144, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 0.99720    36
# 0.99680    35
# 0.99760    35
# 0.99800    29
# 0.99620    28
#            ..
# 0.99684     1
# 0.99764     1
# 0.99473     1
# 0.99320     1
# 0.99651     1
# Name: density, Length: 436, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 3.30    57
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 3.75     1
# 2.74     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: pH, Length: 89, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 0.60    69
# 0.58    68
# 0.54    68
# 0.62    61
# 0.56    60
#         ..
# 1.00     1
# 1.59     1
# 0.33     1
# 1.26     1
# 1.01     1
# Name: sulphates, Length: 96, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 9.500000     139
# 9.400000     103
# 9.800000      78
# 9.200000      72
# 10.000000     67
#             ...
# 9.950000       1
# 9.233333       1
# 9.250000       1
# 9.050000       1
# 10.750000      1
# Name: alcohol, Length: 65, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n

# %% [markdown]
# #all unique values as par respected columns

# %%
DATA.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# #!)from the describe method we can obsarve that the mean value of all colums are equal or close to median(50%)that mense the data
# set han no such skewness
# 2)and some column like fixed acidity,residual sugar,free sulfur dioxide,total sulfur dioxide,has big diffrence in 75% and max value that
# mense thare are some outlairs present

# %% [markdown]
# # univariate

# %%
plt.figure(figsize=(30,25))
f=sns.countplot(x='fixed acidity',data=DATA)
print(DATA['fixed acidity'].value_counts())
plt.show()
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64

# %% [markdown]
# #as par my obsarvation in fixed acidity	column a range between [7.0 to 7.8] has very high count in data.

# %%
plt.figure(figsize=(35,25))
v=sns.countplot(x='volatile acidity',data=DATA)
print(DATA['volatile acidity'].value_counts())
# Out:
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64

# %% [markdown]
# #a volatile acidity column has sum of 143 unique values and the graph shows the count of unique values.

# %%
plt.figure(figsize=(30,25))
c=sns.countplot(x='citric acid',data=DATA)
print(DATA['citric acid'].value_counts())
# Out:
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64

# %% [markdown]
# #as par my obsarvation in citric acid column the most repeted value is " 0 "  and total numbar of unique values is " 80 " .

# %%
plt.figure(figsize=(30,25))
r=sns.countplot(x='residual sugar',data=DATA)
print(DATA['residual sugar'].value_counts())
# Out:
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64

# %% [markdown]
# #a column name residual sugar column has sum of 91 unique values and the graph shows the count of unique values.

# %%
plt.figure(figsize=(30,25))
c=sns.countplot(x='chlorides',data=DATA)
print(DATA['chlorides'].value_counts())
# Out:
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# Name: chlorides, Length: 153, dtype: int64

# %% [markdown]
# #a total numbar of unique value of column name chlorides is '153'and the above plot is represention of count of unique values.

# %%
plt.figure(figsize=(30,25))
f=sns.countplot(x='free sulfur dioxide',data=DATA)
print(DATA['free sulfur dioxide'].value_counts())
dfgh=(DATA['free sulfur dioxide'].value_counts().to_frame())
dfgh.count()
# Out:
# 6.0     138
# 5.0     104
# 10.0     79
# 15.0     78
# 12.0     75
# 7.0      71
# 9.0      62
# 16.0     61
# 17.0     60
# 11.0     59
# 13.0     57
# 8.0      56
# 14.0     50
# 3.0      49
# 18.0     46
# 4.0      41
# 21.0     41
# 19.0     39
# 24.0     34
# 26.0     32
# 23.0     32
# 20.0     30
# 27.0     29
# 25.0     24
# 29.0     23
# 28.0     23
# 22.0     22
# 32.0     22
# 31.0     20
# 34.0     18
# 30.0     16
# 35.0     15
# 36.0     11
# 33.0     11
# 38.0      9
# 41.0      7
# 40.0      6
# 39.0      5
# 48.0      4
# 51.0      4
# 45.0      3
# 1.0       3
# 43.0      3
# 42.0      3
# 52.0      3
# 37.0      3
# 68.0      2
# 55.0      2
# 50.0      2
# 37.5      2
# 53.0      1
# 72.0      1
# 57.0      1
# 47.0      1
# 5.5       1
# 2.0       1
# 46.0      1
# 54.0      1
# 40.5      1
# 66.0      1
# Name: free sulfur dioxide, dtype: int64
# free sulfur dioxide    60
# dtype: int64

# %% [markdown]
# #a total numbar of unique value of column name free sulfur dioxide is ' 60 'and the above plot is represention of unique values.where ('6.0) is repeted most of time.

# %%
plt.figure(figsize=(30,25))
t=sns.countplot(x='total sulfur dioxide',data=DATA)
print()

# %% [markdown]
# #a column name total sulfur dioxide has a "144"unique values and the above plot is represention of count of unique values.

# %%
plt.figure(figsize=(30,25))
d=sns.countplot(x='density',data=DATA)
print(DATA['density'].value_counts())
# Out:
# 0.99720    36
# 0.99680    35
# 0.99760    35
# 0.99800    29
# 0.99620    28
#            ..
# 0.99684     1
# 0.99764     1
# 0.99473     1
# 0.99320     1
# 0.99651     1
# Name: density, Length: 436, dtype: int64

# %% [markdown]
# #a coulmn name density has the most numbar of unique values('436')and the plot represent the count of unique values

# %%
plt.figure(figsize=(30,25))
p=sns.countplot(x='pH',data=DATA)
print(DATA['pH'].value_counts())
# Out:
# 3.30    57
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 3.75     1
# 2.74     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: pH, Length: 89, dtype: int64

# %% [markdown]
# #a coulmn name PH han '89' unique value  and the plot represent the count of unique values

# %%
plt.figure(figsize=(30,25))
p=sns.countplot(x='sulphates',data=DATA)
print(DATA['sulphates'].value_counts())
# Out:
# 0.60    69
# 0.58    68
# 0.54    68
# 0.62    61
# 0.56    60
#         ..
# 1.00     1
# 1.59     1
# 0.33     1
# 1.26     1
# 1.01     1
# Name: sulphates, Length: 96, dtype: int64

# %% [markdown]
# #a coulmn name sulphates han '96' unique value and the plot represent the count of unique values

# %%
plt.figure(figsize=(30,25))
p=sns.countplot(x='alcohol',data=DATA)
print(DATA['alcohol'].value_counts())
# Out:
# 9.500000     139
# 9.400000     103
# 9.800000      78
# 9.200000      72
# 10.000000     67
#             ...
# 9.950000       1
# 9.233333       1
# 9.250000       1
# 9.050000       1
# 10.750000      1
# Name: alcohol, Length: 65, dtype: int64

# %% [markdown]
# #a coulmn name alcohol  han '65' unique value and the plot represent the count of unique values

# %%
plt.figure(figsize=(10,5))
p=sns.countplot(x='quality',data=DATA)
print(DATA['quality'].value_counts())
x=(DATA['quality'].value_counts().to_frame())
x.count()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64
# quality    6
# dtype: int64

# %% [markdown]
# #the target veriable has less number of unique values("6")

# %% [markdown]
# # lets chek the distribution of data in every column.

# %%
plt.figure(figsize=(20,30))
plot_v=1
for col in DATA:
    if plot_v <=11:
        p=plt.subplot(6,2,plot_v)
        sns.distplot(DATA[col],color='red')
        plt.xlabel(col,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plot_v+=1
plt.tight_layout() 
DATA.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# #1)by observing above plots we can notis that the columns like ['PH','density','citric acid'] are perfacty distributed.
# 2)and columns like ['alcohol','fixed acidity','volatile acidity'] has very less sqewness to the right.
# 3)and rest of the cplumns like['sulphates','total sulfur dioxide','free sulfur dioxide','residual sugar','chlorides'] has a very high skewnwss .

# %%
DATA['quality']=DATA['quality'].map({3:'notgood',4:'notgood',5:'notgood',6:'notgood',7:'good',8:'good'})

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   object
# dtypes: float64(11), object(1)
# memory usage: 150.0+ KB

# %%
print(DATA['quality'].value_counts())
# Out:
# notgood    1382
# good        217
# Name: quality, dtype: int64

# %% [markdown]
# #set a arbitrary cutoff for your dependent variable (wine quality) at  7 or higher getting classified as 'good/1' and the remainder as 'not good/0'.
# now the quality colmns is object dtype .
# and the value count for the good is very low as campaier to notgood.

# %% [markdown]
# # bivariate

# %%
sns.scatterplot( x='fixed acidity',y='quality',data=DATA,hue='quality',palette='bright')
plt.title("relation between fixed acidity and taget column ")
# Out:
# Text(0.5, 1.0, 'relation between fixed acidity and taget column ')

# %% [markdown]
# #as observind the above plot relation between those two is normal.

# %%
sns.scatterplot(x='volatile acidity',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between volatile acidityand quality')
# Out:
# Text(0.5, 1.0, 'relation between volatile acidityand quality')

# %%
sns.scatterplot(x='citric acid',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between citric acid and quality')
# Out:
# Text(0.5, 1.0, 'relation between citric acid and quality')

# %%
sns.scatterplot(x='residual sugar',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between residual sugar and quality')
# Out:
# Text(0.5, 1.0, 'relation between residual sugar and quality')

# %%
sns.scatterplot(x='chlorides',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between chlorides and quality')
# Out:
# Text(0.5, 1.0, 'relation between chlorides and quality')

# %%
sns.scatterplot(x='free sulfur dioxide',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between free sulfur dioxide and quality')
# Out:
# Text(0.5, 1.0, 'relation between free sulfur dioxide and quality')

# %%
sns.scatterplot(x='total sulfur dioxide',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between total sulfur dioxide and quality')
# Out:
# Text(0.5, 1.0, 'relation between total sulfur dioxide and quality')

# %%
sns.scatterplot(x='density',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between density and quality')
# Out:
# Text(0.5, 1.0, 'relation between density and quality')

# %%
sns.scatterplot(x='pH',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between pH and quality')
# Out:
# Text(0.5, 1.0, 'relation between pH and quality')

# %%
sns.scatterplot(x='sulphates',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between sulphates and quality')
# Out:
# Text(0.5, 1.0, 'relation between sulphates and quality')

# %%
sns.scatterplot(x='alcohol',y='quality',data=DATA,hue='quality',palette='bright')
plt.title('relation between alcohol and quality')
# Out:
# Text(0.5, 1.0, 'relation between alcohol and quality')

# %% [markdown]
# # let see if data has any outlairs

# %%
plt.figure(figsize=(20,30))
value=1
for col in DATA:
    if value <=11:
        g=plt.subplot(6,2,value)
        sns.boxplot(DATA[col],palette="Set2_r")
        plt.xlabel(col,fontsize=14)
        plt.yticks(rotation=0,fontsize=14)
    value+=1
plt.tight_layout()

# %% [markdown]
# # by observing the boxplot we can say every columns has some outliers let see with zscoor method and remove it.

# %%
from scipy import stats
from scipy.stats import zscore

# %%
z_score = zscore (DATA[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']])
abs_z_score = np.abs(z_score)
filtering_entry = (abs_z_score < 3).all(axis=1)
DATA = DATA[filtering_entry]
DATA
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4  notgood
# 1         9.8  notgood
# 2         9.8  notgood
# 3         9.8  notgood
# 4         9.4  notgood
# ...       ...      ...
# 1594     10.5  notgood
# 1595     11.2  notgood
# 1596     11.0  notgood
# 1597     10.2  notgood
# 1598     11.0  notgood
#
# [1458 rows x 12 columns]

# %%
plt.figure(figsize=(20,30))
value=1
for col in DATA:
    if value <=11:
        g=plt.subplot(6,2,value)
        sns.boxplot(DATA[col],palette="Set2_r")
        plt.xlabel(col,fontsize=14)
        plt.yticks(rotation=0,fontsize=14)
    value+=1
plt.tight_layout()

# %% [markdown]
# #only colums who has a zscore of more then 3 are removed.

# %% [markdown]
# # now lets remove the skewness

# %%
DATA.skew()
# Out:
# fixed acidity           0.820879
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          2.450707
# chlorides               2.307274
# free sulfur dioxide     0.869727
# total sulfur dioxide    1.185230
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# dtype: float64

# %%
DATA['residual sugar']=np.cbrt(DATA['residual sugar'])

# %%
DATA['chlorides']=np.cbrt(DATA['chlorides'])
DATA['total sulfur dioxide']=np.cbrt(DATA['total sulfur dioxide'])

# %%
DATA.skew()
# Out:
# fixed acidity           0.820879
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          0.000000
# chlorides               0.698427
# free sulfur dioxide     0.869727
# total sulfur dioxide    0.052094
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# dtype: float64

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1458 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1458 non-null   float64
#  1   volatile acidity      1458 non-null   float64
#  2   citric acid           1458 non-null   float64
#  3   residual sugar        1458 non-null   float64
#  4   chlorides             1458 non-null   float64
#  5   free sulfur dioxide   1458 non-null   float64
#  6   total sulfur dioxide  1458 non-null   float64
#  7   density               1458 non-null   float64
#  8   pH                    1458 non-null   float64
#  9   sulphates             1458 non-null   float64
#  10  alcohol               1458 non-null   float64
#  11  quality               1458 non-null   object
# dtypes: float64(11), object(1)
# memory usage: 180.4+ KB

# %%
plt.figure(figsize=(20,30))
plot_v=1
for col in DATA:
    if plot_v <=11:
        p=plt.subplot(6,2,plot_v)
        sns.distplot(DATA[col],color='red')
        plt.xlabel(col,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plot_v+=1
plt.tight_layout() 
DATA.skew()
# Out:
# fixed acidity           0.820879
# volatile acidity        0.392097
# citric acid             0.292600
# residual sugar          0.000000
# chlorides               0.698427
# free sulfur dioxide     0.869727
# total sulfur dioxide    0.052094
# density                 0.055543
# pH                      0.113039
# sulphates               0.893297
# alcohol                 0.757396
# dtype: float64

# %% [markdown]
# #removed only those who have very high skewnwss

# %% [markdown]
# #we can se by observing above plot that now there is no data with very high skewnwss present.

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
DATA['quality']=label_encoder.fit_transform(DATA['quality'])

# %%
DATA['quality'].value_counts()
# Out:
# 1    1257
# 0     201
# Name: quality, dtype: int64

# %%
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1458 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1458 non-null   float64
#  1   volatile acidity      1458 non-null   float64
#  2   citric acid           1458 non-null   float64
#  3   residual sugar        1458 non-null   float64
#  4   chlorides             1458 non-null   float64
#  5   free sulfur dioxide   1458 non-null   float64
#  6   total sulfur dioxide  1458 non-null   float64
#  7   density               1458 non-null   float64
#  8   pH                    1458 non-null   float64
#  9   sulphates             1458 non-null   float64
#  10  alcohol               1458 non-null   float64
#  11  quality               1458 non-null   int32
# dtypes: float64(11), int32(1)
# memory usage: 174.7 KB

# %% [markdown]
# #encoding target culmn for creating modal

# %% [markdown]
# # let chek if data has any multicolinearty issue.

# %%
DATA.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.296566     0.699747
# volatile acidity          -0.296566          1.000000    -0.589286
# citric acid                0.699747         -0.589286     1.000000
# residual sugar             0.203808          0.036963     0.188923
# chlorides                  0.212425          0.079194     0.105003
# free sulfur dioxide       -0.146702          0.008824    -0.072097
# total sulfur dioxide      -0.104209          0.100240    -0.023358
# density                    0.660497         -0.000446     0.372338
# pH                        -0.704507          0.252900    -0.521270
# sulphates                  0.200796         -0.350547     0.303401
# alcohol                   -0.018384         -0.212767     0.164420
# quality                   -0.124746          0.268236    -0.226809
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.203808   0.212425            -0.146702
# volatile acidity            0.036963   0.079194             0.008824
# citric acid                 0.188923   0.105003            -0.072097
# residual sugar              1.000000   0.181876             0.010294
# chlorides                   0.181876   1.000000            -0.032540
# free sulfur dioxide         0.010294  -0.032540             1.000000
# total sulfur dioxide        0.100860   0.073622             0.718676
# density                     0.383785   0.387535            -0.039334
# pH                         -0.077378  -0.200811             0.107444
# sulphates                   0.065000   0.001852             0.059713
# alcohol                     0.162026  -0.255492            -0.076400
# quality                    -0.096110   0.133733             0.085448
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.104209  0.660497 -0.704507   0.200796
# volatile acidity                  0.100240 -0.000446  0.252900  -0.350547
# citric acid                      -0.023358  0.372338 -0.521270   0.303401
# residual sugar                    0.100860  0.383785 -0.077378   0.065000
# chlorides                         0.073622  0.387535 -0.200811   0.001852
# free sulfur dioxide               0.718676 -0.039334  0.107444   0.059713
# total sulfur dioxide              1.000000  0.138028  0.028670  -0.003690
# density                           0.138028  1.000000 -0.311217   0.127562
# pH                                0.028670 -0.311217  1.000000  -0.039558
# sulphates                        -0.003690  0.127562 -0.039558   1.000000
# alcohol                          -0.264910 -0.469611  0.136659   0.240684
# quality                           0.183414  0.154221  0.079528  -0.310206
#
#                        alcohol   quality
# fixed acidity        -0.018384 -0.124746
# volatile acidity     -0.212767  0.268236
# citric acid           0.164420 -0.226809
# residual sugar        0.162026 -0.096110
# chlorides            -0.255492  0.133733
# free sulfur dioxide  -0.076400  0.085448
# total sulfur dioxide -0.264910  0.183414
# density              -0.469611  0.154221
# pH                    0.136659  0.079528
# sulphates             0.240684 -0.310206
# alcohol               1.000000 -0.430967
# quality              -0.430967  1.000000

# %%
XD=DATA.drop('quality', axis=1)
yD=DATA['quality']

# %%
cor=DATA.corr()
plt.figure(figsize=(10,8))
sns.heatmap(cor,linewidths=0.1,fmt='.1g',linecolor='black',annot= True,cmap='Blues_r')
# Out:
# <Axes: >

# %% [markdown]
# #the above heatmap represent corelation between colmns to colmns and labal to colmns.
# # hear are some observations
# 1} there is no much relation between colmns towards lable.
# 2} there is high positive corelation between free sulfer dioxide and total sulfar dioxide and aslo between citric acid and fixed acidity.
# 3} and there is nagetive corelation  between pH and fixed acidity
# 4} also there is some coreation between citric acid and volatile acidity

# %% [markdown]
# # LETS SEE THE VIF VALUE

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF['VIF values']=[variance_inflation_factor(XD.values,i)for i in range(len(XD.columns))]
VIF['VIF']=XD.columns
VIF
# Out:
#       VIF values                   VIF
# 0   1.800735e+02         fixed acidity
# 1   1.946111e+01      volatile acidity
# 2   9.072507e+00           citric acid
# 3   1.463018e+06        residual sugar
# 4   1.834544e+03             chlorides
# 5   8.199780e+00   free sulfur dioxide
# 6   4.426225e+02  total sulfur dioxide
# 7   1.552341e+06               density
# 8   1.630444e+03                    pH
# 9   3.295284e+01             sulphates
# 10  2.412597e+02               alcohol

# %% [markdown]
# #by observing VIF value we can drop the citric acidity column

# %%
XD.drop('citric acid', axis=1,inplace=True)

# %%
XD
# Out:
#       fixed acidity  volatile acidity  residual sugar  chlorides  \
# 0               7.4             0.700        1.000004   0.751010
# 1               7.8             0.880        1.000005   0.772528
# 2               7.8             0.760        1.000005   0.767124
# 3              11.2             0.280        1.000004   0.749906
# 4               7.4             0.700        1.000004   0.751010
# ...             ...               ...             ...        ...
# 1594            6.2             0.600        1.000004   0.765252
# 1595            5.9             0.550        1.000004   0.734212
# 1596            6.3             0.510        1.000005   0.751010
# 1597            5.9             0.645        1.000004   0.749906
# 1598            6.0             0.310        1.000007   0.740566
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0              1.479668  0.99780  3.51       0.56
# 1                    25.0              1.595501  0.99680  3.20       0.68
# 2                    15.0              1.557716  0.99700  3.26       0.65
# 3                    17.0              1.576059  0.99800  3.16       0.58
# 4                    11.0              1.479668  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0              1.522670  0.99490  3.45       0.58
# 1595                 39.0              1.547854  0.99512  3.52       0.76
# 1596                 29.0              1.506630  0.99574  3.42       0.75
# 1597                 32.0              1.522670  0.99547  3.57       0.71
# 1598                 18.0              1.514820  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1458 rows x 10 columns]

# %%
VIF=pd.DataFrame()
VIF['VIF values']=[variance_inflation_factor(XD.values,i)for i in range(len(XD.columns))]
VIF['VIF']=XD.columns
VIF
# Out:
#      VIF values                   VIF
# 0  1.616193e+02         fixed acidity
# 1  1.408391e+01      volatile acidity
# 2  1.455492e+06        residual sugar
# 3  1.832913e+03             chlorides
# 4  8.085652e+00   free sulfur dioxide
# 5  4.259363e+02  total sulfur dioxide
# 6  1.545636e+06               density
# 7  1.621191e+03                    pH
# 8  3.292735e+01             sulphates
# 9  2.314242e+02               alcohol

# %% [markdown]
# #now the VIF value in in aceptable range

# %%
from sklearn.preprocessing import StandardScaler

# %%
scal=StandardScaler()
x=pd.DataFrame(scal.fit_transform(XD),columns=XD.columns)
x
# Out:
#       fixed acidity  volatile acidity  residual sugar  chlorides  \
# 0         -0.554045          1.038708       -0.621768  -0.192072
# 1         -0.311190          2.101325        0.456375   0.906854
# 2         -0.311190          1.392914        0.034951   0.630858
# 3          1.753082         -1.440732       -0.621768  -0.248478
# 4         -0.554045          1.038708       -0.621768  -0.192072
# ...             ...               ...             ...        ...
# 1453      -1.282612          0.448365       -0.445456   0.535297
# 1454      -1.464753          0.153194       -0.117844  -1.050015
# 1455      -1.221898         -0.082944        0.034951  -0.192072
# 1456      -1.464753          0.714019       -0.445456  -0.248478
# 1457      -1.404040         -1.263630        1.574960  -0.725479
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.439085             -0.078475  0.629873  1.374768
# 1                1.063952              0.951106  0.047678 -0.823752
# 2               -0.009646              0.615248  0.164117 -0.398232
# 3                0.205073              0.778289  0.746312 -1.107432
# 4               -0.439085             -0.078475  0.629873  1.374768
# ...                   ...                   ...       ...       ...
# 1453             1.815470              0.303747 -1.058494  0.949248
# 1454             2.566989              0.527594 -0.930411  1.445688
# 1455             1.493391              0.161176 -0.569449  0.736488
# 1456             1.815470              0.303747 -0.726642  1.800288
# 1457             0.312433              0.233971 -0.714998  0.523728
#
#       sulphates   alcohol
# 0     -0.635382 -0.996573
# 1      0.289771 -0.604915
# 2      0.058483 -0.604915
# 3     -0.481190 -0.604915
# 4     -0.635382 -0.996573
# ...         ...       ...
# 1453  -0.481190  0.080487
# 1454   0.906541  0.765889
# 1455   0.829444  0.570060
# 1456   0.521060 -0.213256
# 1457   0.135579  0.570060
#
# [1458 rows x 10 columns]

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\garbi\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\garbi\anaconda3\lib\site-packages (from imblearn) (0.10.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\garbi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\garbi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\garbi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.23.5)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\garbi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.2.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\garbi\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.1)

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
x1,y1=sm.fit_resample(x,yD)

# %%
yD.value_counts()
y1.value_counts()
# Out:
# 1    1257
# 0    1257
# Name: quality, dtype: int64

# %% [markdown]
# # the problem of class imbalance is resolve now

# %% [markdown]
# ## lets split the data

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score

# %%
MAXXACU=0
MAXRS=0
for i in range(1,250):
    x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.35,random_state=i)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred=dtc.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>MAXXACU:
        MAXXACU=acc
        MAXRS=i
print('MAX accuracy is',MAXXACU,'BEST rendom state is',MAXRS)
# Out:
# MAX accuracy is 0.9227272727272727 BEST rendom state is 125

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y1,test_size=0.35,random_state=125)

# %% [markdown]
# now we have the best randoom state value "167"
# we will use this value to build models

# %% [markdown]
# # lets start with DecisionTree itself

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.9272727272727272
# [[412  17]
#  [ 47 404]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       429
#            1       0.96      0.90      0.93       451
#
#     accuracy                           0.93       880
#    macro avg       0.93      0.93      0.93       880
# weighted avg       0.93      0.93      0.93       880

# %% [markdown]
# ### score for this decisiontree modal is 92.73% lets cross validate this

# %%
scoredt=cross_val_score(dtc,x1,y1,cv=10)
print(scoredt)
print(scoredt.mean())
print("diffrence in cross_val_score and accuracy_score-", accuracy_score(y_test,preddtc)-(scoredt.mean()))
# Out:
# [0.91666667 0.9047619  0.8531746  0.93253968 0.90836653 0.86055777
#  0.87250996 0.86454183 0.94023904 0.84063745]
# 0.8893995446784292
# diffrence in cross_val_score and accuracy_score- 0.03787318259429806

# %% [markdown]
# ### after observing the cross_val the diffrence is on 3%

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## now lets build the next modal [LogisticRegression]

# %%
lger=LogisticRegression()
lger.fit(x_train,y_train)
predlger=lger.predict(x_test)
print(accuracy_score(y_test,predlger))
print(confusion_matrix(y_test,predlger))
print(classification_report(y_test,predlger))
# Out:
# 0.8090909090909091
# [[356  73]
#  [ 95 356]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81       429
#            1       0.83      0.79      0.81       451
#
#     accuracy                           0.81       880
#    macro avg       0.81      0.81      0.81       880
# weighted avg       0.81      0.81      0.81       880

# %% [markdown]
# ### the accuracy for logisticregression is 81% lets cross validate this

# %%
scorelger=cross_val_score(lger,x1,y1,cv=10)
print(scorelger)
print(scorelger.mean())
print("defreence between accuracy and cross_val_score",accuracy_score(y_test,predlger)-(scorelger.mean()))
# Out:
# [0.86904762 0.86904762 0.76587302 0.83730159 0.87649402 0.75697211
#  0.70517928 0.75298805 0.86454183 0.73306773]
# 0.8030512869158286
# defreence between accuracy and cross_val_score 0.006039622175080472

# %% [markdown]
# ### after cross validatinf the deffrence is less 1%

# %%
from sklearn.svm import SVC

# %% [markdown]
# ## the next modal is SVC

# %%
svm=SVC()
svm.fit(x_train,y_train)
predsvm=svm.predict(x_test)
print(accuracy_score(y_test,predsvm))
print(confusion_matrix(y_test,predsvm))
print(classification_report(y_test,predsvm))
# Out:
# 0.8738636363636364
# [[388  41]
#  [ 70 381]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.87       429
#            1       0.90      0.84      0.87       451
#
#     accuracy                           0.87       880
#    macro avg       0.88      0.87      0.87       880
# weighted avg       0.88      0.87      0.87       880

# %% [markdown]
# ### accuuracy for SVC modal is 87% lets chek croos validation

# %%
scoresvm=cross_val_score(svm,x1,y1,cv=10)
print(scoresvm)
print(scoresvm.mean())
print('dffrence in accuracy and cross_val_score',accuracy_score(y_test,predsvm)-(scoresvm.mean()))
# Out:
# [0.94047619 0.9047619  0.79365079 0.86507937 0.91633466 0.83665339
#  0.79681275 0.86454183 0.92828685 0.82868526]
# 0.867528299500411
# dffrence in accuracy and cross_val_score 0.006335336863225405

# %% [markdown]
# ## as seen the dffrence is 1.6%

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # next modal is RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
predrfc=rfc.predict(x_test)
print(accuracy_score(y_test,predrfc))
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 0.9386363636363636
# [[416  13]
#  [ 41 410]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       429
#            1       0.97      0.91      0.94       451
#
#     accuracy                           0.94       880
#    macro avg       0.94      0.94      0.94       880
# weighted avg       0.94      0.94      0.94       880

# %% [markdown]
# ### the RandomForestClassifier has the highest score of 93.86% lets see the cross validation

# %%
scorerfc=cross_val_score(rfc,x1,y1,cv=10)
print(scorerfc)
print(scorerfc.mean())
print('deffrance of accuracy and cross_val_score',accuracy_score(y_test,predrfc)-(scorerfc.mean()))
# Out:
# [0.96031746 0.96031746 0.88095238 0.92063492 0.96812749 0.88844622
#  0.88844622 0.8685259  0.9561753  0.9123506 ]
# 0.9204293935369632
# deffrance of accuracy and cross_val_score 0.01820697009940042

# %% [markdown]
# ### the deffrance is 1.80%

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %% [markdown]
# # next modal is extratreesclassifier

# %%
edtc=ExtraTreesClassifier()
edtc.fit(x_train,y_train)
prededtc=edtc.predict(x_test)
print(accuracy_score(y_test,prededtc))
print(confusion_matrix(y_test,prededtc))
print(classification_report(y_test,prededtc))
# Out:
# 0.9545454545454546
# [[425   4]
#  [ 36 415]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96       429
#            1       0.99      0.92      0.95       451
#
#     accuracy                           0.95       880
#    macro avg       0.96      0.96      0.95       880
# weighted avg       0.96      0.95      0.95       880

# %% [markdown]
# ### accuracy for ExtraTreesClassifier is 95.45% lets chek the cross validation
# ### the score is highest as compair to othar modals

# %%
scoreedtc=cross_val_score(edtc,x1,y1,cv=10)
print(scoreedtc)
print(scoreedtc.mean())
print('deffrance between accuracy and cross val score is-',(accuracy_score(y_test,prededtc))-(scoreedtc.mean()))
# Out:
# [0.98412698 0.98412698 0.90079365 0.93650794 0.99203187 0.91633466
#  0.90039841 0.92828685 0.96414343 0.95219124]
# 0.9458942009738823
# deffrance between accuracy and cross val score is- 0.00865125357157226

# %% [markdown]
# ### as seen the defreence is only 0.86% ony

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# # the next modal is GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
predgbc=gbc.predict(x_test)
print(accuracy_score(y_test,predgbc))
print(confusion_matrix(y_test,predgbc))
print(classification_report(y_test,predgbc))
# Out:
# 0.9045454545454545
# [[404  25]
#  [ 59 392]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91       429
#            1       0.94      0.87      0.90       451
#
#     accuracy                           0.90       880
#    macro avg       0.91      0.91      0.90       880
# weighted avg       0.91      0.90      0.90       880

# %% [markdown]
# ### the score for GradientBoostingClassifier is 90.45%
# ### lets che the cross val score

# %%
scoregbc=cross_val_score(gbc,x1,y1,cv=10)
print(scoregbc)
print(scoregbc.mean())
print('dffreence of accuracy and cross val score is- ',(accuracy_score(y_test,predgbc))-(scoregbc.mean()))
# Out:
# [0.88095238 0.92460317 0.86111111 0.86507937 0.94422311 0.84860558
#  0.83665339 0.84860558 0.94023904 0.87250996]
# 0.8822582685132486
# dffreence of accuracy and cross val score is-  0.02228718603220592

# %% [markdown]
# ### as seen the doffrance is only 2.28%

# %% [markdown]
# # AS observing all modal accuracy and  compaiering with cross_val_score the extratreesclassifier is the best modal.with the accuracy of 95.45%

# %% [markdown]
# ### lets chek if we can make any improvment by using hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'criterion':['gini','entropy','log_loss'],
           'random_state':[10,50,100,150],
           'max_depth':[1,10,20],
           'n_jobs':[-2,-1,1,2],
           'n_estimators':[10,100,200,300]}

# %%
GCV=GridSearchCV(ExtraTreesClassifier(),parameters,cv=4)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 10, 20],
#                          'n_estimators': [10, 100, 200, 300],
#                          'n_jobs': [-2, -1, 1, 2],
#                          'random_state': [10, 50, 100, 150]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'n_estimators': 300,
#  'n_jobs': -2,
#  'random_state': 150}

# %%
final_model=ExtraTreesClassifier(criterion='gini',random_state=150 ,max_depth= 20,n_jobs=-2 ,n_estimators=300 )
final_model.fit(x_train,y_train)
predf=final_model.predict(x_test)
accuracy=accuracy_score(y_test,predf)
accuracy*100
# Out:
# 95.22727272727273

# %% [markdown]
# # the final modal score is reduse by o.2%

# %% [markdown]
# ### lets chek the ROC curve

# %%
from sklearn import metrics

# %%
fpr,tpr,thresholds=metrics.roc_curve(y_test,predf)

# %%
roc_auc=metrics.auc(fpr,tpr)

# %%
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=final_model)
display.plot()

# %% [markdown]
# # as seen the auc value is 95%

# %% [markdown]
# ### lets save the modal

# %%
import joblib

# %%
joblib.dump(final_model,"Red Wine Quality Prediction Project")
# Out:
# ['Red Wine Quality Prediction Project']

# %% [markdown]
#                                      end
