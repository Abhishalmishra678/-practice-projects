# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
DATA=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/Grades.csv')

# %%
df=DATA

# %%
df.head(10)
# Out:
#    Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102 EE-119  \
# 0  CS-97001     B-     D+     C-         C     C-     D+      D     C-     B-
# 1  CS-97002      A      D     D+         D     B-      C      D      A     D+
# 2  CS-97003      A      B      A        B-     B+      A     B-     B+     A-
# 3  CS-97004      D     C+     D+         D      D     A-     D+     C-      D
# 4  CS-97005     A-     A-     A-        B+      A      A     A-     B+      A
# 5  CS-97006      A     B-      B        D+     C+     A-     C+      B     B+
# 6  CS-97007     B-     C-     A-         D     A-      B      A     B+     A-
# 7  CS-97008     B+     B+     C+         C      C     A-     C-     A-      B
# 8  CS-97009     A-      C     A-        D+      B     A-     A-     A-     B+
# 9  CS-97010      A      B     C+         B      B     A-      C     B-     A-
#
#    ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423 CS-412   CGPA
# ...

# %%
df.tail(10)
# Out:
#      Seat No. PH-121 HS-101 CY-105 HS-105/12 MT-111 CS-105 CS-106 EL-102  \
# 561  CS-97562     B-      B     A-        B+     B-     B+     A-      A
# 562  CS-97563      B      B      A         C      B     B+      B     C-
# 563  CS-97564     A-      B      A        D+     B+     A-      C      A
# 564  CS-97565     A-      D      A         C     B+     B+      C     A-
# 565  CS-97566      F      F      D        C-    NaN     D+      D    NaN
# 566  CS-97567      B      A      A        A-     A+      A     A-     A-
# 567  CS-97568     A+      A      A         A      A      A      A     A-
# 568  CS-97569      B      A     A-        B+      A      A      A      A
# 569  CS-97570      A     B+      D         A      D     D+     B-     C-
# 570  CS-97571      C      D      D         C      C     D+      B     C+
#
#     EE-119  ... CS-312 CS-317 CS-403 CS-421 CS-406 CS-414 CS-419 CS-423  \
# 561      B  ...     B+     B-     B+     D+     C+     B-     B+      C
# ...

# %%
df.shape
# Out:
# (571, 43)

# %% [markdown]
# ## size of the data set is 571 rows and 43 columns.

# %%
df.columns.to_frame()
# Out:
#                    0
# Seat No.    Seat No.
# PH-121        PH-121
# HS-101        HS-101
# CY-105        CY-105
# HS-105/12  HS-105/12
# MT-111        MT-111
# CS-105        CS-105
# CS-106        CS-106
# EL-102        EL-102
# EE-119        EE-119
# ME-107        ME-107
# CS-107        CS-107
# HS-205/20  HS-205/20
# MT-222        MT-222
# EE-222        EE-222
# MT-224        MT-224
# CS-210        CS-210
# CS-211        CS-211
# CS-203        CS-203
# CS-214        CS-214
# EE-217        EE-217
# CS-212        CS-212
# CS-215        CS-215
# MT-331        MT-331
# EF-303        EF-303
# HS-304        HS-304
# CS-301        CS-301
# CS-302        CS-302
# TC-383        TC-383
# MT-442        MT-442
# EL-332        EL-332
# CS-318        CS-318
# CS-306        CS-306
# CS-312        CS-312
# CS-317        CS-317
# CS-403        CS-403
# CS-421        CS-421
# CS-406        CS-406
# CS-414        CS-414
# CS-419        CS-419
# CS-423        CS-423
# CS-412        CS-412
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 43 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Seat No.   571 non-null    object
#  1   PH-121     571 non-null    object
#  2   HS-101     571 non-null    object
#  3   CY-105     570 non-null    object
#  4   HS-105/12  570 non-null    object
#  5   MT-111     569 non-null    object
#  6   CS-105     571 non-null    object
#  7   CS-106     569 non-null    object
#  8   EL-102     569 non-null    object
#  9   EE-119     569 non-null    object
#  10  ME-107     569 non-null    object
#  11  CS-107     569 non-null    object
#  12  HS-205/20  566 non-null    object
#  13  MT-222     566 non-null    object
#  14  EE-222     564 non-null    object
#  15  MT-224     564 non-null    object
#  16  CS-210     564 non-null    object
#  17  CS-211     566 non-null    object
#  18  CS-203     566 non-null    object
# ...

# %% [markdown]
# ## heare are some obsarvetions().
# #### 1) we have data wich contain object data type only CGPA column has flote data type.
# #### 2) as seen in .shape method we have total 43 columns in wich CGPA is our independent vaeiable[label] and rest are dependent veriable.
# #### 3) by obsarving .info mrthod we can all dtypes of columns are correct,but lots of null value present in some columns
# #### 4) by obsarvind label we can say it is a regression problem.
# #### 5) we are going to drop ['SEAT NO'] column becouse it is just a unique identification for every student that we dont need .

# %%
df=df.drop('Seat No.',axis=1)

# %% [markdown]
# ### lets check and fix the problem of null values.

# %%
df.isnull().sum()
# Out:
# PH-121        0
# HS-101        0
# CY-105        1
# HS-105/12     1
# MT-111        2
# CS-105        0
# CS-106        2
# EL-102        2
# EE-119        2
# ME-107        2
# CS-107        2
# HS-205/20     5
# MT-222        5
# EE-222        7
# MT-224        7
# CS-210        7
# CS-211        5
# CS-203        5
# CS-214        6
# EE-217        6
# CS-212        6
# CS-215        6
# MT-331        9
# EF-303       10
# HS-304       10
# CS-301       10
# CS-302       10
# TC-383       10
# MT-442       10
# EL-332        9
# CS-318        9
# CS-306        9
# CS-312       10
# CS-317       12
# CS-403       12
# CS-421       12
# CS-406       85
# CS-414       13
# CS-419       13
# CS-423       14
# CS-412       79
# CGPA          0
# dtype: int64

# %% [markdown]
# ### lets see this on heatmap .

# %%
sns.heatmap(df.isnull(),color='red')
# Out:
# <Axes: >

# %%
print(df['CY-105'].mode())
print(df['HS-105/12'].mode())
print(df['MT-111'].mode())
print(df['CS-106'].mode())
print(df['EL-102'].mode())
print(df['EL-102'].mode())
print(df['ME-107'].mode())                # printing mode of every column that we are filling.
print(df['CS-107'].mode())
print(df['HS-205/20'].mode())
print(df['MT-222'].mode())
print(df['EE-222'].mode())
print(df['MT-224'].mode())
print(df['CS-210'].mode())
print(df['CS-211'].mode())
print(df['CS-203'].mode())
print(df['CS-214'].mode())
print(df['EE-217'].mode())
print(df['CS-212'].mode())
print(df['CS-215'].mode())
print(df['MT-331'].mode())
print(df['EF-303'].mode())
print(df['HS-304'].mode())
print(df['CS-301'].mode())
print(df['CS-302'].mode())
print(df['TC-383'].mode())
print(df['MT-442'].mode())
print(df['EL-332'].mode())
print(df['CS-318'].mode())
print(df['CS-306'].mode())
print(df['CS-312'].mode())
print(df['CS-317'].mode())
print(df['CS-403'].mode())
print(df['CS-421'].mode())
print(df['CS-406'].mode())
print(df['CS-414'].mode())
print(df['CS-419'].mode())
print(df['CS-423'].mode())
print(df['CS-412'].mode())
# Out:
# 0    A
# Name: CY-105, dtype: object
# 0    A
# Name: HS-105/12, dtype: object
# 0    A-
# Name: MT-111, dtype: object
# 0    A-
# Name: CS-106, dtype: object
# 0    A-
# Name: EL-102, dtype: object
# 0    A-
# Name: EL-102, dtype: object
# 0    A-
# Name: ME-107, dtype: object
# 0    A
# Name: CS-107, dtype: object
# 0    A-
# Name: HS-205/20, dtype: object
# 0    A-
# Name: MT-222, dtype: object
# 0    A
# Name: EE-222, dtype: object
# 0    A-
# Name: MT-224, dtype: object
# 0    A-
# Name: CS-210, dtype: object
# 0    A-
# Name: CS-211, dtype: object
# 0    A-
# Name: CS-203, dtype: object
# 0    C
# Name: CS-214, dtype: object
# 0    A-
# Name: EE-217, dtype: object
# 0    A-
# Name: CS-212, dtype: object
# 0    A-
# Name: CS-215, dtype: object
# 0    A
# Name: MT-331, dtype: object
# 0    B
# Name: EF-303, dtype: object
# 0    A-
# Name: HS-304, dtype: object
# 0    A-
# Name: CS-301, dtype: object
# 0    A-
# Name: CS-302, dtype: object
# 0    A
# Name: TC-383, dtype: object
# ...

# %% [markdown]
# ### lets fill it with fillna method.

# %%
df['CY-105'].fillna('A',inplace=True)
df['HS-105/12'].fillna('A',inplace=True)
df['MT-111'].fillna('A-',inplace=True)
df['CS-106'].fillna('A-',inplace=True)
df['EL-102'].fillna('A-',inplace=True)
df['EE-119'].fillna('A-',inplace=True)
df['ME-107'].fillna('A-',inplace=True)
df['CS-107'].fillna('A',inplace=True)
df['HS-205/20'].fillna('A-',inplace=True)
df['MT-222'].fillna('A-',inplace=True)
df['EE-222'].fillna('A',inplace=True)
df['MT-224'].fillna('A-',inplace=True)
df['CS-210'].fillna('A-',inplace=True)
df['CS-211'].fillna('A-',inplace=True)
df['CS-203'].fillna('C',inplace=True)
df['CS-214'].fillna('A-',inplace=True)
df['EE-217'].fillna('A-',inplace=True)
df['CS-212'].fillna('A-',inplace=True)
df['CS-215'].fillna('A',inplace=True)
df['MT-331'].fillna('A',inplace=True)
df['EF-303'].fillna('B',inplace=True)
df['HS-304'].fillna('A-',inplace=True)
df['CS-301'].fillna('A-',inplace=True)
df['CS-302'].fillna('A-',inplace=True)
df['TC-383'].fillna('A',inplace=True)
df['MT-442'].fillna('A-',inplace=True)
df['EL-332'].fillna('A-',inplace=True)
df['CS-318'].fillna('A-',inplace=True)
df['CS-306'].fillna('A-',inplace=True)
df['CS-312'].fillna('A+',inplace=True)
df['CS-317'].fillna('B-',inplace=True)
df['CS-403'].fillna('A',inplace=True)
df['CS-421'].fillna('B',inplace=True)
df['CS-406'].fillna('A-',inplace=True)
df['CS-414'].fillna('A',inplace=True)
df['CS-419'].fillna('A-',inplace=True)
df['CS-423'].fillna('A-',inplace=True)
df['CS-412'].fillna('A-',inplace=True)

# %%
df.isnull().sum()
# Out:
# PH-121       0
# HS-101       0
# CY-105       0
# HS-105/12    0
# MT-111       0
# CS-105       0
# CS-106       0
# EL-102       0
# EE-119       0
# ME-107       0
# CS-107       0
# HS-205/20    0
# MT-222       0
# EE-222       0
# MT-224       0
# CS-210       0
# CS-211       0
# CS-203       0
# CS-214       0
# EE-217       0
# CS-212       0
# CS-215       0
# MT-331       0
# EF-303       0
# HS-304       0
# CS-301       0
# CS-302       0
# TC-383       0
# MT-442       0
# EL-332       0
# CS-318       0
# CS-306       0
# CS-312       0
# CS-317       0
# CS-403       0
# CS-421       0
# CS-406       0
# CS-414       0
# CS-419       0
# CS-423       0
# CS-412       0
# CGPA         0
# dtype: int64

# %%
df.nunique()
# Out:
# PH-121        13
# HS-101        12
# CY-105        13
# HS-105/12     13
# MT-111        13
# CS-105        11
# CS-106        13
# EL-102        13
# EE-119        12
# ME-107        13
# CS-107        14
# HS-205/20     13
# MT-222        14
# EE-222        13
# MT-224        14
# CS-210        14
# CS-211        14
# CS-203        13
# CS-214        13
# EE-217        13
# CS-212        12
# CS-215        14
# MT-331        12
# EF-303        12
# HS-304        14
# CS-301        12
# CS-302        11
# TC-383        12
# MT-442        12
# EL-332        13
# CS-318        14
# CS-306        13
# CS-312        14
# CS-317        12
# CS-403        11
# CS-421        13
# CS-406        14
# CS-414        13
# CS-419        12
# CS-423        12
# CS-412        13
# CGPA         491
# dtype: int64

# %%
df.nunique().plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# ### sa seen in above plot cgpa column has the highest unique value

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('/n'*45)
# Out:
# A-    112
# A     111
# B+     61
# B      57
# B-     56
# D      44
# C      33
# C+     31
# D+     22
# A+     22
# C-     19
# WU      2
# F       1
# Name: PH-121, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# A-    82
# B-    78
# C     68
# B     63
# B+    59
# C-    50
# C+    47
# D     45
# A     38
# D+    36
# A+     4
# F      1
# Name: HS-101, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# A     178
# A-    120
# B+     50
# B      49
# B-     42
# D      31
# A+     31
# C      19
# C+     17
# C-     16
# D+     14
# WU      3
# F       1
# Name: CY-105, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# A     97
# A-    75
# B+    70
# B     57
# D     45
# C     41
# B-    40
# C+    39
# C-    36
# D+    34
# A+    34
# WU     2
# F      1
# Name: HS-105/12, dtype: int64
# ...

# %%
df.describe()
# Out:
#              CGPA
# count  571.000000
# mean     2.954888
# std      0.620552
# min      0.800000
# 25%      2.538000
# 50%      3.029000
# 75%      3.451000
# max      3.985000

# %%
df.skew()
# Out:
# CGPA   -0.497203
# dtype: float64

# %% [markdown]
# ### .describe method show the description of only numerical columns.
# ### as seen in above there is positive  deffrence in mean and median(50%)

# %% [markdown]
# ### that mens there is some skewness is present

# %% [markdown]
# ===================================================================================================================

# %% [markdown]
# ### Now we visualize of data.

# %%
df.columns
# Out:
# Index(['PH-121', 'HS-101', 'CY-105', 'HS-105/12', 'MT-111', 'CS-105', 'CS-106',
#        'EL-102', 'EE-119', 'ME-107', 'CS-107', 'HS-205/20', 'MT-222', 'EE-222',
#        'MT-224', 'CS-210', 'CS-211', 'CS-203', 'CS-214', 'EE-217', 'CS-212',
#        'CS-215', 'MT-331', 'EF-303', 'HS-304', 'CS-301', 'CS-302', 'TC-383',
#        'MT-442', 'EL-332', 'CS-318', 'CS-306', 'CS-312', 'CS-317', 'CS-403',
#        'CS-421', 'CS-406', 'CS-414', 'CS-419', 'CS-423', 'CS-412', 'CGPA'],
#       dtype='object')

# %%
sns.histplot(df['CGPA'])
# Out:
# <Axes: xlabel='CGPA', ylabel='Count'>

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='PH-121',data=df)
# Out:
# <Axes: xlabel='PH-121', ylabel='count'>

# %%
plt.figure(figsize=(6,5))
sns.boxplot(df['CGPA'],palette="Set2_r")
# Out:
# <Axes: >

# %%
plt.figure(figsize=(6,5))
sns.distplot(df['CGPA'],color='red')
# Out:
# <Axes: xlabel='CGPA', ylabel='Density'>

# %%
df['CGPA'].skew()
# Out:
# -0.4972033185635791

# %% [markdown]
# ### we can see our label is little bit of skewed to the left side
# ### we are not cheking outlirs and skewness on object data .

# %% [markdown]
# ### lets encode the columns.

# %%
from sklearn.preprocessing import LabelEncoder 
leb=LabelEncoder()

# %%
for i in df.drop(['CGPA'],axis=1):
    df[i]=leb.fit_transform(df[i])

# %%
df.head(10)
# Out:
#    PH-121  HS-101  CY-105  HS-105/12  MT-111  CS-105  CS-106  EL-102  EE-119  \
# 0       5      10       8          6       8      10       9       8       5
# 1       0       9      10          9       5       6       9       0      10
# 2       0       3       0          5       4       0       5       4       2
# 3       9       7      10          9       9       2      10       8       9
# 4       2       2       2          4       0       0       2       4       0
# 5       0       5       3         10       7       2       7       3       4
# 6       5       8       2          9       2       3       0       4       2
# 7       4       4       7          6       6       2       8       2       3
# 8       2       6       2         10       3       2       2       2       4
# 9       0       3       7          3       3       2       6       5       2
#
#    ME-107  ...  CS-312  CS-317  CS-403  CS-421  CS-406  CS-414  CS-419  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 42 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    int32
#  1   HS-101     571 non-null    int32
#  2   CY-105     571 non-null    int32
#  3   HS-105/12  571 non-null    int32
#  4   MT-111     571 non-null    int32
#  5   CS-105     571 non-null    int32
#  6   CS-106     571 non-null    int32
#  7   EL-102     571 non-null    int32
#  8   EE-119     571 non-null    int32
#  9   ME-107     571 non-null    int32
#  10  CS-107     571 non-null    int32
#  11  HS-205/20  571 non-null    int32
#  12  MT-222     571 non-null    int32
#  13  EE-222     571 non-null    int32
#  14  MT-224     571 non-null    int32
#  15  CS-210     571 non-null    int32
#  16  CS-211     571 non-null    int32
#  17  CS-203     571 non-null    int32
#  18  CS-214     571 non-null    int32
#  19  EE-217     571 non-null    int32
# ...

# %% [markdown]
# ###  Bivariate Analysis

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='PH-121',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='HS-101',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CY-105',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='HS-105/12',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='MT-111',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-105',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-106',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='EL-102',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='EE-119',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='ME-107',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-107',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='HS-205/20',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='MT-222',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='EE-222',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='MT-224',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-210',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-211',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-203',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-214',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='EE-217',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-212',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-215',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='MT-331',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='EF-303',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='HS-304',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-301',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-302',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))  
sns.catplot(x='TC-383',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='MT-442',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='EL-332',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-318',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-306',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-312',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-317',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-403',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-421',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-406',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-414',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-419',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-423',y='CGPA',data=df,kind='bar')

# %%
plt.figure(figsize=(6,4))
sns.catplot(x='CS-412',y='CGPA',data=df,kind='bar')

# %% [markdown]
# ## Multivariate analysis

# %% [markdown]
# ### let chek if data has any multicolinearty issue.

# %%
df.corr()
# Out:
#              PH-121    HS-101    CY-105  HS-105/12    MT-111    CS-105  \
# PH-121     1.000000  0.382436  0.557843   0.498561  0.468968  0.609990
# HS-101     0.382436  1.000000  0.335074   0.473132  0.432742  0.400713
# CY-105     0.557843  0.335074  1.000000   0.510123  0.538380  0.578573
# HS-105/12  0.498561  0.473132  0.510123   1.000000  0.494731  0.482406
# MT-111     0.468968  0.432742  0.538380   0.494731  1.000000  0.393684
# CS-105     0.609990  0.400713  0.578573   0.482406  0.393684  1.000000
# CS-106     0.293963  0.312019  0.378223   0.499093  0.500729  0.286324
# EL-102     0.423942  0.349412  0.447539   0.360304  0.555895  0.353949
# EE-119     0.579964  0.309697  0.467250   0.400303  0.409161  0.507357
# ME-107     0.533558  0.336545  0.464418   0.320137  0.471685  0.455470
# CS-107     0.477761  0.495906  0.481277   0.540405  0.488977  0.503239
# HS-205/20  0.296428  0.178344  0.261281   0.179766  0.328574  0.192982
# ...

# %%
cor=df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(cor,linewidths=0.1,fmt='.1g',linecolor='black',annot= True,cmap='Blues_r')
# Out:
# <Axes: >

# %% [markdown]
# ### as seen in the heat map every column is corelated with the label .

# %% [markdown]
# ### lets split the label and independent variable

# %%
dfx=df.drop('CGPA', axis=1)
dfy=df['CGPA']

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 41 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PH-121     571 non-null    int32
#  1   HS-101     571 non-null    int32
#  2   CY-105     571 non-null    int32
#  3   HS-105/12  571 non-null    int32
#  4   MT-111     571 non-null    int32
#  5   CS-105     571 non-null    int32
#  6   CS-106     571 non-null    int32
#  7   EL-102     571 non-null    int32
#  8   EE-119     571 non-null    int32
#  9   ME-107     571 non-null    int32
#  10  CS-107     571 non-null    int32
#  11  HS-205/20  571 non-null    int32
#  12  MT-222     571 non-null    int32
#  13  EE-222     571 non-null    int32
#  14  MT-224     571 non-null    int32
#  15  CS-210     571 non-null    int32
#  16  CS-211     571 non-null    int32
#  17  CS-203     571 non-null    int32
#  18  CS-214     571 non-null    int32
#  19  EE-217     571 non-null    int32
# ...

# %%
dfy.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 571 entries, 0 to 570
# Series name: CGPA
# Non-Null Count  Dtype
# --------------  -----
# 571 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %% [markdown]
# ### lets scal the independent variables with standard scaler

# %%
from sklearn.preprocessing import StandardScaler
scal=StandardScaler()

# %%
dfx=pd.DataFrame(scal.fit_transform(dfx),columns=dfx.columns)

# %%
dfx.describe()
# Out:
#              PH-121        HS-101        CY-105     HS-105/12      MT-111  \
# count  5.710000e+02  5.710000e+02  5.710000e+02  5.710000e+02  571.000000
# mean   4.977532e-17 -8.399586e-17 -7.466298e-17  1.866575e-17    0.000000
# std    1.000877e+00  1.000877e+00  1.000877e+00  1.000877e+00    1.000877
# min   -1.242052e+00 -1.822504e+00 -9.784900e-01 -1.326478e+00   -1.305012
# 25%   -5.850701e-01 -7.444826e-01 -9.784900e-01 -7.010287e-01   -0.635204
# 50%   -2.565794e-01 -2.580202e-02 -3.033023e-01 -7.557965e-02    0.034605
# 75%    7.288927e-01  6.928786e-01  5.406822e-01  8.625939e-01    0.704413
# max    2.699837e+00  2.130240e+00  3.072636e+00  2.426216e+00    2.713839
#
#              CS-105        CS-106        EL-102        EE-119        ME-107  \
# count  5.710000e+02  5.710000e+02  5.710000e+02  5.710000e+02  5.710000e+02
# mean  -1.119945e-16 -2.488766e-17 -3.733149e-17  8.710682e-17 -6.221915e-17
# ...

# %% [markdown]
# ### lets import all the libreries for models

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression  
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
MAXXACU=0
MAXRS=0
for i in range(1,150):
    x_train,x_test,y_train,y_test=train_test_split(dfx,dfy,test_size=0.25,random_state=i)
    ler=LinearRegression()
    ler.fit(x_train,y_train)
    pred=ler.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>MAXXACU:
        MAXXACU=acc
        MAXRS=i
print('MAX R2_score is-',MAXXACU,'BEST rendom state is',MAXRS)
# Out:
# MAX R2_score is- 0.9659022431888445 BEST rendom state is 72

# %% [markdown]
# ### now we get the best rendom state for aur data

# %%
x_train,x_test,y_train,y_test=train_test_split(dfx,dfy,test_size=0.25,random_state=MAXRS)

# %%
def evaluation(model, prediction, x_train, y_train, x_test, y_test):
    print('mean absolute error : %.2f' % mean_absolute_error(y_test,prediction)) 
    print('mean_squared error: %.2f' % mean_squared_error(y_test, prediction, squared=False)) 
    print('R2 score : %.2f' % r2_score(y_test, prediction)) 
    print('Train Accuracy :', model.score(x_train, y_train)) 
    print('Test Accuracy :', model.score(x_test, y_test))

# %% [markdown]
# ### making all modal as a singal modal

# %%
models = {
    'LinearRegression' : LinearRegression(),
    'DecisionTree'     : DecisionTreeRegressor(),
    'RandomForest'     : RandomForestRegressor(),
    'Ridge'            : Ridge(),
    'Lasso'            : Lasso(),
    'SVR'              : SVR(),
    'ElasticNet'       : ElasticNet(),
    'KNeighborsRegressor':KNeighborsRegressor(),
    'GradientBoostingRegressor':GradientBoostingRegressor(),
    'XGBRegressor'      :  XGBRegressor()
}

# %% [markdown]
# ### now lets train all modal at once,¶

# %%
for model_name, model in models.items():
    model.fit(x_train, y_train)
    prediction1 = model.predict(x_test)
    print('Model: {}'.format(model_name))
    print(evaluation(model, prediction1, x_train, y_train, x_test, y_test), 
          '\n')
# Out:
# Model: LinearRegression
# mean absolute error : 0.09
# mean_squared error: 0.12
# R2 score : 0.97
# Train Accuracy : 0.9159202793321422
# Test Accuracy : 0.9659022431888445
# None
#
# Model: DecisionTree
# mean absolute error : 0.17
# mean_squared error: 0.24
# R2 score : 0.86
# Train Accuracy : 1.0
# Test Accuracy : 0.8555425866126757
# None
#
# Model: RandomForest
# mean absolute error : 0.11
# mean_squared error: 0.16
# R2 score : 0.94
# Train Accuracy : 0.9849200118207317
# Test Accuracy : 0.9391636373397128
# None
#
# Model: Ridge
# mean absolute error : 0.09
# mean_squared error: 0.12
# R2 score : 0.97
# Train Accuracy : 0.9159195437302954
# Test Accuracy : 0.96607284953176
# None
#
# Model: Lasso
# mean absolute error : 0.54
# mean_squared error: 0.63
# R2 score : -0.00
# Train Accuracy : 0.0
# Test Accuracy : -7.02413021478332e-05
# None
#
# Model: SVR
# mean absolute error : 0.07
# mean_squared error: 0.10
# R2 score : 0.97
# Train Accuracy : 0.961515570998539
# ...

# %% [markdown]
# ### lets cross validate all models with cross_val_score method

# %%
for model_name, model in models.items():
    score=cross_val_score(model,dfx,dfy,cv=5,scoring='r2')
    print('Model: {}'.format(model_name))
    print(score)
    print(model.score(x_test, y_test))
    print(score.mean())
    print('deffrence between r2_score and cross val_score',(model.score(x_test, y_test)) -(score.mean()))
    print('===============================================================================================')
# Out:
# Model: LinearRegression
# [0.89598899 0.93078543 0.89494215 0.94497155 0.84777089]
# 0.9659022431888445
# 0.9028918009594662
# deffrence between r2_score and cross val_score 0.06301044222937835
# ...
# Model: DecisionTree
# [0.83554226 0.78408003 0.88395703 0.75165763 0.72540699]
# 0.8555425866126757
# 0.7961287875991232
# deffrence between r2_score and cross val_score 0.05941379901355248
# ...
# Model: RandomForest
# [0.9029656  0.93062832 0.94112693 0.9139796  0.83716249]
# 0.9391636373397128
# 0.9051725895460863
# deffrence between r2_score and cross val_score 0.033991047793626494
# ...
# Model: Ridge
# [0.89611873 0.93084977 0.89513818 0.94529273 0.8479184 ]
# 0.96607284953176
# 0.9030635626836382
# deffrence between r2_score and cross val_score 0.06300928684812179
# ...
# Model: Lasso
# [-0.00643799 -0.0037979  -0.00364638 -0.00242138 -0.02411396]
# -7.02413021478332e-05
# -0.008083520623131602
# deffrence between r2_score and cross val_score 0.008013279320983769
# ...
# Model: SVR
# ...

# %% [markdown]
# ### after obsarving all the score and error methods we can say that GradientBoostingRegressor is our best model

# %% [markdown]
# ### now lets use hyper parameter tuning on our best model

# %%
parameters  = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.5],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt'],
    'subsample': [0.8, 1.0]           }

# %%
from sklearn.model_selection import GridSearchCV

# %%
GCV=GridSearchCV(GradientBoostingRegressor(),parameters,cv=9)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=9, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5],
#                          'max_depth': [3, 4, 5],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300],
#                          'subsample': [0.8, 1.0]})

# %%
GCV.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 3,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 300,
#  'subsample': 0.8}

# %%
final_model=GradientBoostingRegressor(n_estimators=300,learning_rate=0.1,max_depth=3,min_samples_split=2,min_samples_leaf=1,max_features='sqrt',subsample=0.8)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
print('final modal score test ',model.score(x_test, y_test))
print('r2_score',r2_score(y_test,pred))
print('mean absolute error',mean_absolute_error(y_test,pred))
print('mean squared error',mean_squared_error(y_test,pred))
print('root mean squared error',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# final modal score test  0.9324505277298701
# r2_score 0.9695586993277169
# mean absolute error 0.08027746824816161
# mean squared error 0.012082953779841143
# root mean squared error 0.10992248987282423

# %% [markdown]
# ## final model r2_score is = 96.95%

# %% [markdown]
# ### lets save the modal

# %%
import joblib

# %%
joblib.dump(final_model,"Student grades prediction")
# Out:
# ['Student grades prediction']
