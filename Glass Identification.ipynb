# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
DATA=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset3/main/glass.csv')

# %%
df=DATA

# %%
df.head(10)
# Out:
#     1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83   0.0    0.00    1
# 1   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78   0.0    0.00    1
# 2   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22   0.0    0.00    1
# 3   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07   0.0    0.00    1
# 4   6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07   0.0    0.26    1
# 5   7  1.51743  13.30  3.60  1.14  73.09  0.58  8.17   0.0    0.00    1
# 6   8  1.51756  13.15  3.61  1.05  73.24  0.57  8.24   0.0    0.00    1
# 7   9  1.51918  14.04  3.58  1.37  72.08  0.56  8.30   0.0    0.00    1
# 8  10  1.51755  13.00  3.60  1.36  72.99  0.57  8.40   0.0    0.11    1
# 9  11  1.51571  12.72  3.46  1.56  73.20  0.67  8.09   0.0    0.24    1

# %%
df.tail(10)
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 203  205  1.51617  14.95   0.0  2.27  73.30  0.00  8.71  0.67     0.0    7
# 204  206  1.51732  14.95   0.0  1.80  72.99  0.00  8.61  1.55     0.0    7
# 205  207  1.51645  14.94   0.0  1.87  73.11  0.00  8.67  1.38     0.0    7
# 206  208  1.51831  14.39   0.0  1.82  72.86  1.41  6.47  2.88     0.0    7
# 207  209  1.51640  14.37   0.0  2.74  72.85  0.00  9.45  0.54     0.0    7
# 208  210  1.51623  14.14   0.0  2.88  72.61  0.08  9.18  1.06     0.0    7
# 209  211  1.51685  14.92   0.0  1.99  73.06  0.00  8.40  1.59     0.0    7
# 210  212  1.52065  14.36   0.0  2.02  73.42  0.00  8.44  1.64     0.0    7
# 211  213  1.51651  14.38   0.0  1.94  73.61  0.00  8.48  1.57     0.0    7
# 212  214  1.51711  14.23   0.0  2.08  73.36  0.00  8.62  1.67     0.0    7

# %%
df.columns.to_frame()
# Out:
#                0
# 1              1
# 1.52101  1.52101
# 13.64      13.64
# 4.49        4.49
# 1.10        1.10
# 71.78      71.78
# 0.06        0.06
# 8.75        8.75
# 0.00        0.00
# 0.00.1    0.00.1
# 1.1          1.1

# %% [markdown]
# ### as we can see we dont have columns name
# ### first let give the columns name as mention in the problem statement.

# %%
df.rename(
    columns={"1":"Idnumber",
             "1.52101":"refractive index",
            "13.64":"Sodium",
            "4.49":"Magnesium",
            "1.10":"Aluminum",
            "71.78":"Silicon",
            "0.06":"Potassium",
            "8.75":"Calcium",
            "0.00":"Barium",
            "0.00.1":"Iron",
            "1.1":"Type of glass"}
                                      ,inplace=True)

# %%
df.head(10)
# Out:
#    Idnumber  refractive index  Sodium  Magnesium  Aluminum  Silicon  \
# 0         2           1.51761   13.89       3.60      1.36    72.73
# 1         3           1.51618   13.53       3.55      1.54    72.99
# 2         4           1.51766   13.21       3.69      1.29    72.61
# 3         5           1.51742   13.27       3.62      1.24    73.08
# 4         6           1.51596   12.79       3.61      1.62    72.97
# 5         7           1.51743   13.30       3.60      1.14    73.09
# 6         8           1.51756   13.15       3.61      1.05    73.24
# 7         9           1.51918   14.04       3.58      1.37    72.08
# 8        10           1.51755   13.00       3.60      1.36    72.99
# 9        11           1.51571   12.72       3.46      1.56    73.20
#
#    Potassium  Calcium  Barium  Iron  Type of glass
# 0       0.48     7.83     0.0  0.00              1
# 1       0.39     7.78     0.0  0.00              1
# 2       0.57     8.22     0.0  0.00              1
# ...

# %%
df.columns.to_frame()
# Out:
#                                  0
# Idnumber                  Idnumber
# refractive index  refractive index
# Sodium                      Sodium
# Magnesium                Magnesium
# Aluminum                  Aluminum
# Silicon                    Silicon
# Potassium                Potassium
# Calcium                    Calcium
# Barium                      Barium
# Iron                          Iron
# Type of glass        Type of glass

# %%
df.shape
# Out:
# (213, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Idnumber          213 non-null    int64
#  1   refractive index  213 non-null    float64
#  2   Sodium            213 non-null    float64
#  3   Magnesium         213 non-null    float64
#  4   Aluminum          213 non-null    float64
#  5   Silicon           213 non-null    float64
#  6   Potassium         213 non-null    float64
#  7   Calcium           213 non-null    float64
#  8   Barium            213 non-null    float64
#  9   Iron              213 non-null    float64
#  10  Type of glass     213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %% [markdown]
# #### heare are some obsarvation
# ##### 1) we have total 11 columns and 213 rows in data set in wich "type of glass" column in our dependent variable[label]and rest are independent variable
# ##### 2)as mention in problem statement and by obsarving data we can say it is a multy-classification problem
# ##### 3)as par my prefrence column name "Id number" is not requared or usfull in any way becouse it is just a unique id for every row nothing else.
# ##### 4) all dtypes are correct as par there coulmns data type

# %%
df=df.drop('Idnumber',axis=1)

# %%
df.columns.to_frame()
# Out:
#                                  0
# refractive index  refractive index
# Sodium                      Sodium
# Magnesium                Magnesium
# Aluminum                  Aluminum
# Silicon                    Silicon
# Potassium                Potassium
# Calcium                    Calcium
# Barium                      Barium
# Iron                          Iron
# Type of glass        Type of glass

# %% [markdown]
# ### IDNUMBER COLUMN IS REMOVED

# %%
df.isnull().sum()
# Out:
# refractive index    0
# Sodium              0
# Magnesium           0
# Aluminum            0
# Silicon             0
# Potassium           0
# Calcium             0
# Barium              0
# Iron                0
# Type of glass       0
# dtype: int64

# %%
sns.heatmap(df.isnull(),color='red',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### no null value present in data set

# %%
df.nunique()
# Out:
# refractive index    177
# Sodium              142
# Magnesium            93
# Aluminum            117
# Silicon             132
# Potassium            65
# Calcium             143
# Barium               34
# Iron                 32
# Type of glass         6
# dtype: int64

# %%
df.nunique().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### sa seen in above plot refractive index column has the highest unique value
# ### and labal has lowest unique value count.

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('/n'*45)
# Out:
# 1.52152    3
# 1.51590    3
# 1.51645    3
# 1.51761    2
# 1.51613    2
#           ..
# 1.51625    1
# 1.51569    1
# 1.51605    1
# 1.51588    1
# 1.51651    1
# Name: refractive index, Length: 177, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 13.21    5
# 13.02    5
# 13.00    5
# 12.85    4
# 12.86    4
#         ..
# 13.34    1
# 13.31    1
# 14.17    1
# 13.51    1
# 14.23    1
# Name: Sodium, Length: 142, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 0.00    42
# 3.48     8
# 3.58     8
# 3.54     8
# 3.52     7
#         ..
# 3.46     1
# 3.73     1
# 3.97     1
# 3.89     1
# 1.78     1
# Name: Magnesium, Length: 93, dtype: int64
# /n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n/n
# 1.54    8
# 1.19    6
# 1.56    5
# 1.29    5
# 1.43    5
#        ..
# 1.61    1
# 0.88    1
# 1.05    1
# 0.65    1
# 1.94    1
# ...

# %% [markdown]
# ### all unique values as par respected columns

# %%
DATA.describe()
# Out:
#          Idnumber  refractive index      Sodium   Magnesium    Aluminum  \
# count  213.000000        213.000000  213.000000  213.000000  213.000000
# mean   108.000000          1.518353   13.406761    2.676056    1.446526
# std     61.631972          0.003039    0.818371    1.440453    0.499882
# min      2.000000          1.511150   10.730000    0.000000    0.290000
# 25%     55.000000          1.516520   12.900000    2.090000    1.190000
# 50%    108.000000          1.517680   13.300000    3.480000    1.360000
# 75%    161.000000          1.519150   13.830000    3.600000    1.630000
# max    214.000000          1.533930   17.380000    3.980000    3.500000
#
#           Silicon   Potassium     Calcium      Barium        Iron  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000
# mean    72.655023    0.499108    8.957934    0.175869    0.057277
# std      0.774052    0.653035    1.426435    0.498245    0.097589
# ...

# %% [markdown]
# ## hear are some obsarvation
# ### 1) the value of mean median(50%)is little high in {Magnesium,Silicon,Potassium,}colums
# ### little bit low in {Sodium,Aluminum,Calcium,Barium,Iron,Type of glass}
# ### 2) thet mens little bit skewnwss is present in those columns .
# ### 3) and deffrance between 75% and max valu is also little bit high in {Sodium,Aluminum,Potassium,Calcium,Barium,Iron,Type of glass
# ### that mens some outliers are also present }
# ### 4) count of all values are also equal to the data set shape

# %% [markdown]
# ## lets chek for the skewness

# %%
df.skew()
# Out:
# refractive index    1.639658
# Sodium              0.457318
# Magnesium          -1.154323
# Aluminum            0.900017
# Silicon            -0.744546
# Potassium           6.549276
# Calcium             2.040591
# Barium              3.406749
# Iron                1.747173
# Type of glass       1.108861
# dtype: float64

# %% [markdown]
# #### as seen in skew method lots of skewness problem is present

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## univaret anlysis

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Type of glass',data=df)
# Out:
# <Axes: xlabel='Type of glass', ylabel='count'>

# %% [markdown]
# ### lets map the [type of glass]colum as par the problem statement.

# %%
df['Type of glass']=df['Type of glass'].map({1:'window glass', 2: 'window glass',3:'window glass',5:'non-window glass',6:'non-window glass',7:'non-window glass'})

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Type of glass',data=df)
# Out:
# <Axes: xlabel='Type of glass', ylabel='count'>

# %% [markdown]
# ### as seen in the count plot class imbalnce is present.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## biverate anlysis.

# %% [markdown]
# ### as encode [type of glass for the anlysis]

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder()

# %%
df['Type of glass']=label_encoder.fit_transform(df['Type of glass'])

# %%
print(df['Type of glass'])
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 208    0
# 209    0
# 210    0
# 211    0
# 212    0
# Name: Type of glass, Length: 213, dtype: int32

# %% [markdown]
# ### from now on 0=window glass and 1= non window glass

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   refractive index  213 non-null    float64
#  1   Sodium            213 non-null    float64
#  2   Magnesium         213 non-null    float64
#  3   Aluminum          213 non-null    float64
#  4   Silicon           213 non-null    float64
#  5   Potassium         213 non-null    float64
#  6   Calcium           213 non-null    float64
#  7   Barium            213 non-null    float64
#  8   Iron              213 non-null    float64
#  9   Type of glass     213 non-null    int32
# dtypes: float64(9), int32(1)
# memory usage: 15.9 KB

# %%
sns.lmplot( x='Sodium',y='refractive index',hue='Type of glass',data=df,palette='bright')
plt.title("relation between refractive index and Sodium ")
# Out:
# Text(0.5, 1.0, 'relation between refractive index and Sodium ')

# %%
sns.lmplot( x='Magnesium',y='refractive index',hue='Type of glass',data=df,palette='bright')
plt.title("relation between refractive index and Magnesium  ")
# Out:
# Text(0.5, 1.0, 'relation between refractive index and Magnesium  ')

# %%
sns.lmplot( x='Aluminum',y='refractive index',hue='Type of glass',data=df,palette='bright')
plt.title("relation between refractive index and Aluminum ")
# Out:
# Text(0.5, 1.0, 'relation between refractive index and Aluminum ')

# %%
sns.lmplot( x='Silicon',y='refractive index',hue='Type of glass',data=df,palette='bright')
plt.title("relation between refractive index and Silicon ")
# Out:
# Text(0.5, 1.0, 'relation between refractive index and Silicon ')

# %%
sns.lmplot( x='Potassium',y='refractive index',hue='Type of glass',data=df,palette='bright')
plt.title("relation between refractive index and Potassium ")
# Out:
# Text(0.5, 1.0, 'relation between refractive index and Potassium ')

# %%
sns.lmplot( x='Calcium',y='refractive index',hue='Type of glass',data=df,palette='bright')
plt.title("relation between refractive index and Calcium  ")
# Out:
# Text(0.5, 1.0, 'relation between refractive index and Calcium  ')

# %%
sns.lmplot( x='Barium',y='refractive index',hue='Type of glass',data=df,palette='bright')
plt.title("relation between refractive index and Barium  ")
# Out:
# Text(0.5, 1.0, 'relation between refractive index and Barium  ')

# %%
sns.lmplot( x='Iron',y='refractive index',hue='Type of glass',data=df,palette='bright')
plt.title("relation between refractive index and Iron ")
# Out:
# Text(0.5, 1.0, 'relation between refractive index and Iron ')

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## mulivariate anlysis

# %%
sns.pairplot(df)

# %% [markdown]
# ================================================================================================================================

# %% [markdown]
# ### let see if data has any outlairs

# %%
plt.figure(figsize=(20,30))
value=1
for col in df:
    if value <=10:
        g=plt.subplot(5,2,value)
        sns.boxplot(df[col],palette="Set2_r")
        plt.xlabel(col,fontsize=14)
        plt.yticks(rotation=0,fontsize=14)
    value+=1
plt.tight_layout()

# %% [markdown]
# ### as deen in box plot we have some outliars in data set

# %% [markdown]
# ### lets cross chek and remove it

# %%
from scipy import stats
from scipy.stats import zscore

# %%
z_score = zscore (df)
abs_z_score = np.abs(z_score)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   refractive index  213 non-null    float64
#  1   Sodium            213 non-null    float64
#  2   Magnesium         213 non-null    float64
#  3   Aluminum          213 non-null    float64
#  4   Silicon           213 non-null    float64
#  5   Potassium         213 non-null    float64
#  6   Calcium           213 non-null    float64
#  7   Barium            213 non-null    float64
#  8   Iron              213 non-null    float64
#  9   Type of glass     213 non-null    int32
# dtypes: float64(9), int32(1)
# memory usage: 15.9 KB

# %%
np.where(z_score>3)
# Out:
# (array([104, 105, 105, 105, 106, 106, 109, 110, 111, 111, 130, 144, 161,
#         162, 162, 170, 170, 171, 171, 173, 183, 183, 188, 200, 200, 202,
#         206, 212], dtype=int64),
#  array([6, 0, 6, 7, 0, 6, 6, 6, 0, 6, 6, 8, 8, 3, 7, 3, 5, 3, 5, 8, 1, 4,
#         7, 4, 5, 7, 7, 7], dtype=int64))

# %%
df.iloc[105]
# Out:
# refractive index     1.53125
# Sodium              10.73000
# Magnesium            0.00000
# Aluminum             2.10000
# Silicon             69.81000
# Potassium            0.58000
# Calcium             13.30000
# Barium               3.15000
# Iron                 0.28000
# Type of glass        1.00000
# Name: 105, dtype: float64

# %% [markdown]
# ### we are not removing outliars coz of vert less data set
# ### and all those outlaire data point can be acceptions.

# %% [markdown]
# =====================================================================================================================

# %% [markdown]
# ### now lets chek for skewness and remove it

# %%
plt.figure(figsize=(20,30))
plot_v=1
for col in df:
    if plot_v <=9:
        p=plt.subplot(5,2,plot_v)
        sns.distplot(df[col],color='red')
        plt.xlabel(col,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plot_v+=1
plt.tight_layout() 
df.skew()
# Out:
# refractive index    1.639658
# Sodium              0.457318
# Magnesium          -1.154323
# Aluminum            0.900017
# Silicon            -0.744546
# Potassium           6.549276
# Calcium             2.040591
# Barium              3.406749
# Iron                1.747173
# Type of glass      -1.229860
# dtype: float64

# %%
df['refractive index']=np.cbrt(df['refractive index'])
df['Magnesium']=np.cbrt(df['Magnesium'])
df['Aluminum']=np.cbrt(df['Aluminum'])
df['Silicon']=np.cbrt(df['Silicon'])
df['Potassium']=np.cbrt(df['Potassium'])
df['Calcium']=np.cbrt(df['Calcium'])
df['Barium']=np.cbrt(df['Barium'])
df['Iron']=np.cbrt(df['Iron'])          # removing skewness with cube root(cbrt) methode

# %% [markdown]
# ### now cheking displot again

# %%
plt.figure(figsize=(20,30))
plot_v=1
for col in df:
    if plot_v <=9:
        p=plt.subplot(5,2,plot_v)
        sns.distplot(df[col],color='red')
        plt.xlabel(col,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plot_v+=1
plt.tight_layout() 
df.skew()
# Out:
# refractive index    1.631276
# Sodium              0.457318
# Magnesium          -1.434030
# Aluminum           -0.212025
# Silicon            -0.791299
# Potassium          -0.602542
# Calcium             1.402709
# Barium              2.065220
# Iron                0.887382
# Type of glass      -1.229860
# dtype: float64

# %% [markdown]
# ### its get better

# %% [markdown]
# ============================================================================================================

# %% [markdown]
# ### let chek if data has any multicolinearty issue.

# %%
df.corr()
# Out:
#                   refractive index    Sodium  Magnesium  Aluminum   Silicon  \
# refractive index          1.000000 -0.193363  -0.117130 -0.416574 -0.540359
# Sodium                   -0.193363  1.000000  -0.279296  0.078387 -0.069387
# Magnesium                -0.117130 -0.279296   1.000000 -0.374347 -0.165647
# Aluminum                 -0.416574  0.078387  -0.374347  1.000000  0.026821
# Silicon                  -0.540359 -0.069387  -0.165647  0.026821  1.000000
# Potassium                -0.209223 -0.539691   0.447219  0.117749 -0.177126
# Calcium                   0.804777 -0.264899  -0.398879 -0.288266 -0.192163
# Barium                   -0.091052  0.419484  -0.547593  0.508589 -0.009782
# Iron                      0.135799 -0.196262   0.097130 -0.056761 -0.081790
# Type of glass             0.132497 -0.453504   0.701493 -0.520400 -0.143296
#
#                   Potassium   Calcium    Barium      Iron  Type of glass
# ...

# %% [markdown]
# ### lets plot a heatmap for clear obsarvation

# %%
cor=df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(cor,linewidths=0.1,fmt='.1g',linecolor='black',annot= True,cmap='Blues_r')
# Out:
# <Axes: >

# %% [markdown]
# ### obsarvations
# ##### 1) refractive index is highly correlated with Calcium
# ##### 2) Sodium	,Aluminum,Barium is also mediam coreleted with label
# ##### 3) othar columns are also has some corelation but it was low .

# %% [markdown]
# ### we are dropping Barium becouse it was corelleted with Magnesium as well as with label also.

# %%
df1=df.drop('Barium',axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   refractive index  213 non-null    float64
#  1   Sodium            213 non-null    float64
#  2   Magnesium         213 non-null    float64
#  3   Aluminum          213 non-null    float64
#  4   Silicon           213 non-null    float64
#  5   Potassium         213 non-null    float64
#  6   Calcium           213 non-null    float64
#  7   Iron              213 non-null    float64
#  8   Type of glass     213 non-null    int32
# dtypes: float64(8), int32(1)
# memory usage: 14.3 KB

# %% [markdown]
# ### lets split the label and independent variable

# %%
dfx=df1.drop('Type of glass', axis=1)
dfy=df1['Type of glass']

# %%
dfx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   refractive index  213 non-null    float64
#  1   Sodium            213 non-null    float64
#  2   Magnesium         213 non-null    float64
#  3   Aluminum          213 non-null    float64
#  4   Silicon           213 non-null    float64
#  5   Potassium         213 non-null    float64
#  6   Calcium           213 non-null    float64
#  7   Iron              213 non-null    float64
# dtypes: float64(8)
# memory usage: 13.4 KB

# %%
dfy.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 213 entries, 0 to 212
# Series name: Type of glass
# Non-Null Count  Dtype
# --------------  -----
# 213 non-null    int32
# dtypes: int32(1)
# memory usage: 980.0 bytes

# %% [markdown]
# ### lets scal the independent variables with standard scaler

# %%
from sklearn.preprocessing import StandardScaler
scal=StandardScaler()

# %%
dfx=pd.DataFrame(scal.fit_transform(dfx),columns=dfx.columns)

# %%
dfx.describe()
# Out:
#        refractive index        Sodium     Magnesium      Aluminum  \
# count      2.130000e+02  2.130000e+02  2.130000e+02  2.130000e+02
# mean       8.320939e-14 -1.717979e-15 -2.668705e-16 -3.335881e-16
# std        1.002356e+00  1.002356e+00  1.002356e+00  1.002356e+00
# min       -2.381778e+00 -3.278544e+00 -1.984950e+00 -3.458021e+00
# 25%       -6.048977e-01 -6.206894e-01  1.438058e-01 -4.276650e-01
# 50%       -2.216163e-01 -1.307623e-01  5.381638e-01 -6.022388e-02
# 75%        2.638133e-01  5.183912e-01  5.668380e-01  4.649645e-01
# max        5.127214e+00  4.866495e+00  6.536372e-01  3.065928e+00
#
#             Silicon     Potassium       Calcium          Iron
# count  2.130000e+02  2.130000e+02  2.130000e+02  2.130000e+02
# mean  -1.322677e-14  1.667941e-17  1.267635e-15  1.250956e-17
# std    1.002356e+00  1.002356e+00  1.002356e+00  1.002356e+00
# min   -3.719446e+00 -2.020518e+00 -3.069491e+00 -6.817127e-01
# ...

# %% [markdown]
# ### lets import all the libreries for models

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier

# %% [markdown]
# ### first lets get a best rendom stete value .

# %%
MAXXACU=0
MAXRS=0
for i in range(1,250):
    x_train,x_test,y_train,y_test=train_test_split(dfx,dfy,test_size=0.30,random_state=i)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred=dtc.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>MAXXACU:
        MAXXACU=acc
        MAXRS=i
print('MAX accuracy is',MAXXACU,'BEST rendom state is',MAXRS)
# Out:
# MAX accuracy is 0.984375 BEST rendom state is 45

# %%
x_train,x_test,y_train,y_test=train_test_split(dfx,dfy,test_size=0.30,random_state=MAXRS)

# %% [markdown]
# ### now we have the best randoom state value "167"
# ### we will use this value to build models

# %%
def evaluation(model, prediction, x_train, y_train, x_test, y_test):
    print(accuracy_score(y_test,prediction))
    print(confusion_matrix(y_test,prediction))
    print(classification_report(y_test,prediction))   # defing the all evaluation method to one

# %% [markdown]
# ### making all modal as a singal modal

# %%
models = {
    'LogisticRegression'         : LogisticRegression(),
    'DecisionTreeClassifier'     : DecisionTreeClassifier(),
    'RandomForestClassifier'     : RandomForestClassifier(),
    'SVC'                        : SVC(),
    'KNeighborsClassifier'       : KNeighborsClassifier(),
    'GaussianNB'                 : GaussianNB(),
    'GradientBoostingClassifier' : GradientBoostingClassifier(),
    'MLPClassifier'              :MLPClassifier()
}

# %% [markdown]
# ### now lets train all modal at once,

# %%
for model_name, model in models.items():
    model.fit(x_train, y_train)
    prediction1 = model.predict(x_test)
    print('Model: {}'.format(model_name))
    print(evaluation(model, prediction1, x_train, y_train, x_test, y_test), 
          '\n')
# Out:
# Model: LogisticRegression
# 0.953125
# [[ 8  1]
#  [ 2 53]]
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84         9
#            1       0.98      0.96      0.97        55
#
#     accuracy                           0.95        64
#    macro avg       0.89      0.93      0.91        64
# weighted avg       0.96      0.95      0.95        64
#
# None
#
# Model: DecisionTreeClassifier
# 0.96875
# [[ 9  0]
#  [ 2 53]]
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90         9
#            1       1.00      0.96      0.98        55
#
#     accuracy                           0.97        64
#    macro avg       0.91      0.98      0.94        64
# weighted avg       0.97      0.97      0.97        64
#
# None
#
# Model: RandomForestClassifier
# 0.953125
# [[ 9  0]
#  [ 3 52]]
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# ## ALL MODEL SCORE:
# ## 'LogisticRegression'         :0.953125
# ##    'DecisionTreeClassifier'     :0.96875
# ##   'RandomForestClassifier'     : 0.953125
# ##    'SVC'                        :0.984375
# ##    'KNeighborsClassifier'       : 0.9375
# ##    'GaussianNB'                 : 0.953125
# ##    'GradientBoostingClassifier' : 0.953125
# ##   'MLPClassifier'              :0.9375

# %% [markdown]
# ### lets cross validate all models with cross_val_score method

# %%
for model_name, model in models.items():
    score=cross_val_score(model,dfx,dfy,cv=5,)
    print('Model: {}'.format(model_name))
    print(score)
    print(model.score(x_test, y_test))
    print(score.mean())
    print("                                                                                  ")
    print('deffrence between accuracy_score and cross val_score',(model.score(x_test, y_test)) -(score.mean()))
    print("                                                                                  ")
# Out:
# Model: LogisticRegression
# [0.93023256 0.86046512 0.81395349 0.78571429 0.97619048]
# 0.953125
# 0.873311184939092
#
# deffrence between accuracy_score and cross val_score 0.07981381506090801
#
# Model: DecisionTreeClassifier
# [0.90697674 0.93023256 0.8372093  0.85714286 1.        ]
# 0.96875
# 0.906312292358804
#
# deffrence between accuracy_score and cross val_score 0.06243770764119605
#
# Model: RandomForestClassifier
# [0.88372093 0.88372093 0.90697674 0.73809524 1.        ]
# 0.953125
# 0.8825027685492802
#
# deffrence between accuracy_score and cross val_score 0.07062223145071977
#
# Model: SVC
# [0.90697674 0.88372093 0.86046512 0.76190476 1.        ]
# 0.984375
# 0.8826135105204873
#
# deffrence between accuracy_score and cross val_score 0.10176148947951269
#
# Model: KNeighborsClassifier
# [0.88372093 0.88372093 0.86046512 0.80952381 0.97619048]
# 0.9375
# 0.8827242524916944
#
# deffrence between accuracy_score and cross val_score 0.054775747508305606
#
# ...

# %% [markdown]
# ### the DecisionTreeClassifier model is best model for oour data

# %% [markdown]
# #### now lets use hyper parameter tuning on our best model

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={
    'criterion':['gini','entropy','log_loss'],
           'max_depth':[10,50,100,],
           'min_samples_split':[4,6,8],
           'min_samples_leaf':[1,2,3],
           'max_features':['auto', 'sqrt', 'log2']
                                                    }

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),parameters,cv=4)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [10, 50, 100],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [4, 6, 8]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'log_loss',
#  'max_depth': 10,
#  'max_features': 'log2',
#  'min_samples_leaf': 1,
#  'min_samples_split': 4}

# %%
final_model=DecisionTreeClassifier(criterion='log_loss',max_depth=10,max_features ='log2',min_samples_leaf=1,min_samples_split=4)
final_model.fit(x_train,y_train)
predf=final_model.predict(x_test)
accuracy=accuracy_score(y_test,predf)
accuracy*100
# Out:
# 90.625

# %% [markdown]
# ### we did det decrese in accuracy_score after using hyper parameter tuning.

# %% [markdown]
# ### lets chek the ROC curve

# %%
from sklearn import metrics

# %%
fpr,tpr,thresholds=metrics.roc_curve(y_test,predf)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=final_model)
display.plot()

# %% [markdown]
# ### as seen the auc value is 90%

# %% [markdown]
# ### lets save the modal¶

# %%
import joblib

# %%
joblib.dump(final_model,"Glass Identification")
# Out:
# ['Glass Identification']

# %% [markdown]
# ==================================================================================================================
